# %%
import yfinance as yf

# Define the ticker symbol
ticker_symbol = 'NKE'

# Create a ticker object
ticker = yf.Ticker(ticker_symbol)

# Download historical data
historical_data = ticker.history(start="1990-01-01", end="2022-12-31")
# historical_data = ticker.history(period="730d", interval='1h')

# %%
historical_data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1990-01-02 00:00:00-05:00    0.599724    0.633511    0.591277    0.633511
# 1990-01-03 00:00:00-05:00    0.633511    0.641958    0.619433    0.619433
# 1990-01-04 00:00:00-05:00    0.619433    0.622249    0.594093    0.606763
# 1990-01-05 00:00:00-05:00    0.606763    0.625065    0.605356    0.625065
# 1990-01-08 00:00:00-05:00    0.625065    0.627880    0.608171    0.622249
# ...                               ...         ...         ...         ...
# 2022-12-23 00:00:00-05:00  110.811549  111.823176  110.496606  110.945160
# 2022-12-27 00:00:00-05:00  111.155140  112.806191  110.534800  112.195396
# 2022-12-28 00:00:00-05:00  112.214469  112.844347  109.714025  109.733116
# 2022-12-29 00:00:00-05:00  110.782922  112.682110  110.515700  111.994965
# 2022-12-30 00:00:00-05:00  111.241017  111.899532  110.487066  111.670486
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
data = yf.download(tickers='BTC-USD', period='max', interval='1d')
# Out:
# /var/folders/ln/sphck21d1ldb9687pbhzy38c0000gn/T/ipykernel_88733/3788455195.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers='BTC-USD', period='max', interval='1d')
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
# Price               Close           High            Low           Open  \
# Ticker            BTC-USD        BTC-USD        BTC-USD        BTC-USD
# Date
# 2014-09-17     457.334015     468.174011     452.421997     465.864014
# 2014-09-18     424.440002     456.859985     413.104004     456.859985
# 2014-09-19     394.795990     427.834991     384.532013     424.102997
# 2014-09-20     408.903992     423.295990     389.882996     394.673004
# 2014-09-21     398.821014     412.425995     393.181000     408.084991
# ...                   ...            ...            ...            ...
# 2025-11-11  102997.468750  107428.257812  102457.328125  105996.859375
# 2025-11-12  101663.187500  105297.234375  100836.617188  103011.437500
# 2025-11-13   99697.492188  104005.492188   97988.718750  101674.148438
# 2025-11-14   94397.789062   99804.429688   94000.734375   99694.703125
# 2025-11-15   96027.835938   96627.281250   94509.156250   94509.156250
#
# Price             Volume
# ...

# %%
data = data.xs("BTC-USD", axis=1, level="Ticker")

# %%
data
# Out:
# Price               Close           High            Low           Open  \
# Date
# 2014-09-17     457.334015     468.174011     452.421997     465.864014
# 2014-09-18     424.440002     456.859985     413.104004     456.859985
# 2014-09-19     394.795990     427.834991     384.532013     424.102997
# 2014-09-20     408.903992     423.295990     389.882996     394.673004
# 2014-09-21     398.821014     412.425995     393.181000     408.084991
# ...                   ...            ...            ...            ...
# 2025-11-11  102997.468750  107428.257812  102457.328125  105996.859375
# 2025-11-12  101663.187500  105297.234375  100836.617188  103011.437500
# 2025-11-13   99697.492188  104005.492188   97988.718750  101674.148438
# 2025-11-14   94397.789062   99804.429688   94000.734375   99694.703125
# 2025-11-15   96027.835938   96627.281250   94509.156250   94509.156250
#
# Price             Volume
# Date
# 2014-09-17      21056800
# 2014-09-18      34483200
# ...

# %%
import pandas as pd
df = pd.read_csv('BTCUSD_Candlestick_1_D_ASK_08.05.2017-16.10.2021.csv')

# %%
df
# Out:
#                      Gmt time   Open   High    Low  Close        Volume
# 0     07.05.2017 21:00:00.000   1559   1681   1557   1658  1.872044e+06
# 1     08.05.2017 21:00:00.000   1658   1753   1626   1747  1.330136e+06
# 2     09.05.2017 21:00:00.000   1713   1769   1677   1752  1.916895e+06
# 3     10.05.2017 21:00:00.000   1784   1887   1777   1857  1.613521e+06
# 4     11.05.2017 21:00:00.000   1836   1836   1651   1692  2.550428e+06
# ...                       ...    ...    ...    ...    ...           ...
# 1301  12.10.2021 21:00:00.000  55433  57543  54328  57047  2.013182e+03
# 1302  13.10.2021 21:00:00.000  57078  58568  56906  57505  2.001020e+03
# 1303  14.10.2021 21:00:00.000  57533  62922  56940  62587  2.235774e+03
# 1304  15.10.2021 21:00:00.000  62587  62608  60223  61077  1.943311e+03
# 1305  16.10.2021 21:00:00.000  61077  61498  59043  59467  2.443833e+03
#
# [1306 rows x 6 columns]

# %%
df = df[df['Volume']!=0]

# %%
df
# Out:
#                      Gmt time   Open   High    Low  Close        Volume
# 0     07.05.2017 21:00:00.000   1559   1681   1557   1658  1.872044e+06
# 1     08.05.2017 21:00:00.000   1658   1753   1626   1747  1.330136e+06
# 2     09.05.2017 21:00:00.000   1713   1769   1677   1752  1.916895e+06
# 3     10.05.2017 21:00:00.000   1784   1887   1777   1857  1.613521e+06
# 4     11.05.2017 21:00:00.000   1836   1836   1651   1692  2.550428e+06
# ...                       ...    ...    ...    ...    ...           ...
# 1301  12.10.2021 21:00:00.000  55433  57543  54328  57047  2.013182e+03
# 1302  13.10.2021 21:00:00.000  57078  58568  56906  57505  2.001020e+03
# 1303  14.10.2021 21:00:00.000  57533  62922  56940  62587  2.235774e+03
# 1304  15.10.2021 21:00:00.000  62587  62608  60223  61077  1.943311e+03
# 1305  16.10.2021 21:00:00.000  61077  61498  59043  59467  2.443833e+03
#
# [1304 rows x 6 columns]

# %%
import plotly.io as pio
pio.renderers.default = "browser"

# %%
dfp1 = df[:]
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x = dfp1.index,
            open=dfp1['Open'],
            high=dfp1['High'],
            low=dfp1['Low'],
            close=dfp1['Close']
        )
    ]
)
fig.show()

# %%
import yfinance as yf

data = yf.download(tickers='BTC-USD', period='max', interval='1d')
# Out:
# /var/folders/ln/sphck21d1ldb9687pbhzy38c0000gn/T/ipykernel_88733/4107715292.py:3: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# [*********************100%***********************]  1 of 1 completed

# %%
import matplotlib.pyplot as plt
plt.plot(data.index, data.Close, '#86BC25')
plt.show()

# %%
data.head()
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker         BTC-USD     BTC-USD     BTC-USD     BTC-USD   BTC-USD
# Date
# 2014-09-17  457.334015  468.174011  452.421997  465.864014  21056800
# 2014-09-18  424.440002  456.859985  413.104004  456.859985  34483200
# 2014-09-19  394.795990  427.834991  384.532013  424.102997  37919700
# 2014-09-20  408.903992  423.295990  389.882996  394.673004  36863600
# 2014-09-21  398.821014  412.425995  393.181000  408.084991  26580100

# %%
import plotly.graph_objects as go

fig = go.Figure(data=go.Candlestick(
    x=data.index,
    open=data['Open'],
    high=data['High'],
    low=data['Low'],
    close=data['Close']
))
fig.show()

# %%
print(data.dtypes)
# Out:
# Price   Ticker
# Close   BTC-USD    float64
# High    BTC-USD    float64
# Low     BTC-USD    float64
# Open    BTC-USD    float64
# Volume  BTC-USD      int64
# dtype: object

# %%
data.index
# Out:
# DatetimeIndex(['2014-09-17', '2014-09-18', '2014-09-19', '2014-09-20',
#                '2014-09-21', '2014-09-22', '2014-09-23', '2014-09-24',
#                '2014-09-25', '2014-09-26',
#                ...
#                '2025-11-07', '2025-11-08', '2025-11-09', '2025-11-10',
#                '2025-11-11', '2025-11-12', '2025-11-13', '2025-11-14',
#                '2025-11-15', '2025-11-16'],
#               dtype='datetime64[ns]', name='Date', length=4079, freq=None)

# %%
data = yf.download(tickers='BTC-USD', period='max', interval='1d')
data = data.xs("BTC-USD", axis=1, level="Ticker")
# Out:
# /var/folders/ln/sphck21d1ldb9687pbhzy38c0000gn/T/ipykernel_88733/2341433908.py:1: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# [*********************100%***********************]  1 of 1 completed

# %%
dfp1 = data[:100]
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(
    x=dfp1.index,
    open=dfp1['Open'],
    high=dfp1['High'],
    low=dfp1['Low'],
    close=dfp1['Close'],
    increasing_line_color='yellow',
    decreasing_line_color='blue',
),
go.Scatter(x=dfp1.index, y=[380]*len(dfp1), line=dict(color='red', width=2), name="Support/Resistance"),
go.Scatter(x=dfp1.index, y=[470]*len(dfp1), line=dict(color='red', width=2), name="Support/Resistance"),
go.Scatter(x=dfp1.index, y=dfp1.High, mode='markers', marker=dict(size=5, color='MediumPurple'), name="Signal")])

fig.update_layout(xaxis_rangeslider_visible=False)
fig.update_layout(paper_bgcolor='black', plot_bgcolor='black',
                  margin_l=0, margin_b=0, margin_r=0, margin_t=0)


fig.update_xaxes(showline=True, linewidth=2, linecolor='white', gridcolor='black')
fig.update_yaxes(showline=True, linewidth=2, linecolor='white', gridcolor='black')



fig.show()
